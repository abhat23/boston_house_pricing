# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Lets Load Boston Data Set

# %%
from sklearn.datasets import load_boston
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from sklearn.datasets import load_boston
#
# File c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\Lib\site-packages\sklearn\datasets\__init__.py:156, in __getattr__(name)
#     105 if name == "load_boston":
#     106     msg = textwrap.dedent(
#     107         """
#     108         `load_boston` has been removed from scikit-learn since version 1.2.
#    (...)
#     154         """
#     155     )
# --> 156     raise ImportError(msg)
#     157 try:
#     158     return globals()[name]
#
# ImportError:
# `load_boston` has been removed from scikit-learn since version 1.2.
#
# The Boston housing prices dataset has an ethical problem: as
# investigated in [1], the authors of this dataset engineered a
# ...

# %%
boston = load_boston()
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
boston.keys()
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
print(boston.DESCR)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
print(boston.data)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
print(boston.feature_names)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
print(boston.target)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
dataset = pd.read_csv(r"C:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\HousingData.csv")
#df = pd.DataFrame(boston.data,columns=boston.feature_names)
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df['Price'] = boston.target
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df['Price'] = boston.target
#
# NameError: name 'boston' is not defined

# %%
df
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
df.iloc[0,:]
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
df.info()
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
df.describe()
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
#Check the Missing Values
df.isnull().sum()
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
df.isna().sum()
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
#Correlation is v important to understand relationship between variables
#Pearson Correlation - -1 to 1 , if 1 then postively correlated, if -1 then negatively correlated and if 0 no relationship
#if high correlation between independent variable, then multicolinearity, we can drop one independent feature
#Correlation between Dependent and Independent Feature,
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
df.corr()
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
df.columns
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
import seaborn as sns
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
sns.pairplot(df)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
plt.scatter(df['CRIM'],df['Price'])
plt.xlabel('Crime Rate')
plt.ylabel('Price')
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
plt.scatter(df['RM'],df['Price'])
plt.xlabel('RM')
plt.ylabel('Price')
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
import seaborn as sns
sns.regplot(x='RM',y='Price',data=df)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
sns.regplot(x='LSTAT',y='Price',data=df)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
sns.regplot(x='CHAS',y='Price',data=df)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
Y = df.iloc[:,-1]
X = df.iloc[:,:-1]
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
X
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
Y
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3, random_state=42)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
X_train
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
X_test
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
X_train = scalar.fit_transform(X_train)
X_test = scalar.transform(X_test)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
X_train
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
X_test
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
lr.fit(X_train,Y_train)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
print(lr.coef_)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
print(lr.intercept_)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
#On which paramaters model is trained
lr.get_params()
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
y_pred = lr.predict(X_test)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
y_pred
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
plt.scatter(Y_test,y_pred)
#Its linear plotting
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
residuals = Y_test - y_pred
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
residuals
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
sns.displot(residuals,kind='kde') 
#Outliers are present (10-30) and not a normal distribution between -10 to 100
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
plt.scatter(y_pred,residuals) #Uniform distribution
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_test,y_pred)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
mse
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(Y_test,y_pred)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
mae
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
print(mse)
print(mae)
print(np.sqrt(mse))
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
from sklearn.metrics import r2_score
score = r2_score(Y_test,y_pred)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
score
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %% [markdown]
# # New Data Prediction

# %%
boston.data[0].reshape(1,-1).shape
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
data = scalar.transform(boston.data[0].reshape(1,-1))
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
lr.predict(data)
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %% [markdown]
# # Pickling the Model FIle

# %%
import pickle
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
pickle.dump(lr,open('regmodel.pkl','wb'))
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
pickled_model = pickle.load(open('regmodel.pkl','rb'))
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'

# %%
pickled_model.predict(scalar.transform(boston.data[0].reshape(1,-1)))
# Out:
# Running cells with 'c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\aarti.bhat\OneDrive - Accenture\Documents\4.Learning\25. AI Projects\boston_house_pricing\venv ipykernel --update-deps --force-reinstall'
